# %%
import numpy as np

# %%
data = np.load('../data/jaccard_masks.npz', allow_pickle=True)
data_jaccard = data['arr_0']

# %%
print(f"{np.mean(data_jaccard)} {np.std(data_jaccard)}")
# Out:
# 0.9008282312224732 0.09732210095196168
